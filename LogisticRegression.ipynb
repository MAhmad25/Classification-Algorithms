# %% [markdown]
# <a href="https://colab.research.google.com/github/MAhmad25/Classification-Algorithms/blob/master/LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as n
